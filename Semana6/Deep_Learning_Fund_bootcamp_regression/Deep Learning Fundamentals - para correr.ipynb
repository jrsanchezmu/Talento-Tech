# %% [markdown]
# # Deep Learning Fundamentals

# %% [markdown]
# ## What is deep learning?
#
# **Deep learning** is a subset of machine learning, consisting of algorithms inspired by the structure of a human brain. It is particularly useful for working with unstructured data which nevertheless follows some internal rules: images, videos, text, etc.

# %% [markdown]
# ## Introduction to neural networks
#
#
# <img src="Perceptron_5_unidades.png" width="400">

# %% [markdown]
# For example, this is how the above would look for a simple home price prediction model:
#
# <img src="perceptron.png" width="600">

# %% [markdown]
# Here are some examples of neural network architectures:
#
# ![](nnexamples.jpg)

# %% [markdown]
# Here are some examples of problems which can be tackled with neural networks:
#
# <img src="tblapplications.png" width="400">

# %% [markdown]
# ### How does it work?
#
# ![](example.png)

# %%
import numpy as np

# Define input data
input_data = np.array([3,5])

#Define weights
weights = { 'node_0': np.array([2, 4]), 
            'node_1': np.array([ 4, -5]), 
            'output': np.array([2, 7])}

# Calculate node 0 value: node_0_value
node_0_value = (input_data * weights['node_0']).sum()
print(node_0_value)

# Calculate node 1 value: node_1_value
node_1_value = (input_data * weights['node_1']).sum()
print(node_1_value)

# Put node values into array: hidden_layer_outputs
hidden_layer_outputs = np.array([node_0_value, node_1_value])
print(hidden_layer_outputs)

# Calculate output: output
output = (hidden_layer_outputs*weights['output']).sum()

# Print output
print(output)
# Out:
# 26
# -13
# [ 26 -13]
# -39

# %% [markdown]
# ## Activation Functions
#
# For neural networks to achieve their maximum predictive power, we must apply something called an **activation function** in the hidden layers. An activation function allows the model to capture non-linearities - without these, our neural network would be no different from a standard linear model! These functions are asssociated to each node, and are applied to node inputs to produce node outputs:
#
# ![](activation.png)
#
# The **Rectified Linear Unit (ReLU)** function is the most widely-used activation function in neural networks today. One of the greatest advantages ReLU has over other activation functions is that it does not activate all neurons at the same time. From the image for ReLU function above, we’ll notice that it converts all negative inputs to zero and the neuron does not get activated. This makes it very computationally efficient as few neurons are activated at any given time. In practice, ReLU converges six times faster than other functions like `tanh` and sigmoid.

# %%
def relu(input):
    '''relu activation function'''
    output = max(0, input)
    return(output)

# Calculate node 0 value: node_0_output
node_0_input = (input_data * weights['node_0']).sum()
node_0_output = relu(node_0_input)

# Calculate node 1 value: node_1_output
node_1_input = (input_data * weights['node_1']).sum()
node_1_output = relu(node_1_input)

# Put node values into array: hidden_layer_outputs
hidden_layer_outputs = np.array([node_0_output, node_1_output])

# Calculate model output (do not apply relu)
model_output = (hidden_layer_outputs * weights['output']).sum()

# Print model output
print(model_output)
# Out:
# 52

# %%
# Define predict_with_network()
def predict_with_network(input_data_row, weights):

    # Calculate node 0 value
    node_0_input = (input_data_row * weights['node_0']).sum()
    node_0_output = relu(node_0_input)

    # Calculate node 1 value
    node_1_input = (input_data_row * weights['node_1']).sum()
    node_1_output = relu(node_1_input)

    # Put node values into array: hidden_layer_outputs
    hidden_layer_outputs = np.array([node_0_output, node_1_output])
    
    # Calculate model output
    input_to_final_layer = (hidden_layer_outputs * weights['output']).sum()
    model_output = relu(input_to_final_layer)
    
    # Return model output
    return(model_output)

input_data = [np.array([3, 5]), np.array([ 1, -1]), np.array([0, 0]), np.array([8, 4])]

# Create empty list to store prediction results
results = []
for input_data_row in input_data:
    # Append prediction to results
    results.append(predict_with_network(input_data_row,weights))

# Print results
print(results)
# Out:
# [52, 63, 0, 148]

# %% [markdown]
# <img src="multiplehiddenlayers1.png" width="500">

# %%
def predict_with_network(input_data):
     # Calculate node 0 in the first hidden layer
    node_0_0_input = (input_data * weights['node_0_0']).sum()
    node_0_0_output = relu(node_0_0_input)

    # Calculate node 1 in the first hidden layer
    node_0_1_input = (input_data * weights['node_0_1']).sum()
    node_0_1_output = relu(node_0_1_input)

    # Put node values into array: hidden_0_outputs
    hidden_0_outputs = np.array([node_0_0_output, node_0_1_output])

    # Calculate node 0 in the second hidden layer
    node_1_0_input = (hidden_0_outputs * weights['node_1_0']).sum()
    node_1_0_output = relu(node_1_0_input)

    # Calculate node 1 in the second hidden layer
    node_1_1_input = (hidden_0_outputs * weights['node_1_1']).sum()
    node_1_1_output = relu(node_1_1_input)

    # Put node values into array: hidden_1_outputs
    hidden_1_outputs = np.array([node_1_0_output, node_1_1_output])
    
    # Calculate output here: model_output
    model_output = (hidden_1_outputs * weights['output']).sum()
    
    # Return model_output
    return(model_output)
weights ={  'node_0_0': np.array([2, 4]),
            'node_0_1': np.array([ 4, -5]),
            'node_1_0': np.array([-1,  2]),
            'node_1_1': np.array([1, 2]),
            'output': np.array([2, 7])}

input_data = np.array([3, 5])
output = predict_with_network(input_data)
print(output)
# Out:
# 182

# %% [markdown]
# <img src="forward.png" width="400">

# %% [markdown]
# ### Optimizing weights
#
# However, just because we have a neural network does not mean that we will have a good model. We need to optimize the weights to get this:
#
# <img src="optimization.png" width="400">

# %% [markdown]
# The **loss function** gives a single number which summarizes the degree of error in the model's predictions. Similar to the mean-squared error (MSE) of a linear moodel, the loss function gives us a sense of how well the model fits the data. Our goal then is to find the weights for the neural network which minimizes the loss function.
#
# <img src="loss.png" width="400">

# %% [markdown]
# There is a method called **gradient descent** which we use in order to find the optimal weights. This method comes from calculus:
#
# <img src="gradient_descent_1d.gif" width="400">

# %%
# Define predict_with_network()
def predict_with_network(input_data_row, weights):

    # Calculate node 0 value
    node_0_input = (input_data_row * weights['node_0']).sum()
    node_0_output = relu(node_0_input)

    # Calculate node 1 value
    node_1_input = (input_data_row * weights['node_1']).sum()
    node_1_output = relu(node_1_input)

    # Put node values into array: hidden_layer_outputs
    hidden_layer_outputs = np.array([node_0_output, node_1_output])
    
    # Calculate model output
    input_to_final_layer = (hidden_layer_outputs * weights['output']).sum()
    model_output = relu(input_to_final_layer)
    
    # Return model output
    return(model_output)
    
# The data point you will make a prediction for
input_data = np.array([0, 3])

# Sample weights
weights_0 = {'node_0': [2, 1],
             'node_1': [1, 2],
             'output': [1, 1]
            }

# The actual target value, used to calculate the error
target_actual = 3

# Make prediction using original weights
model_output_0 = predict_with_network(input_data, weights_0)

# Calculate error: error_0
error_0 = model_output_0 - target_actual

# Create weights that cause the network to make perfect prediction (3): weights_1
weights_1 = {'node_0': [2, 1],
             'node_1': [1, 2],
             'output': [1, 0]
            }

# Make prediction using new weights: model_output_1
model_output_1 = predict_with_network(input_data, weights_1)

# Calculate error: error_1
error_1 = model_output_1 - target_actual

# Print error_0 and error_1
print(error_0)
print(error_1)
# Out:
# 6
# 0

# %%
from sklearn.metrics import mean_squared_error

# Create model_output_0 
model_output_0 = []
# Create model_output_1
model_output_1 = []
 
input_data = [np.array([0, 3]), np.array([1, 2]), np.array([-1, -2]), np.array([4, 0])] 
target_actuals = [1, 3, 5, 7]

weights_0 = {
    'node_0': np.array([2, 1]), 
    'node_1': np.array([1, 2]), 
    'output': np.array([1, 1])}
weights_1 = {
    'node_0': np.array([2, 1]),
    'node_1': np.array([1. , 1.5]),
    'output': np.array([1. , 1.5])}
# Loop over input_data
for row in input_data:
    # Append prediction to model_output_0
    model_output_0.append(predict_with_network(row, weights_0))
    
    # Append prediction to model_output_1
    model_output_1.append(predict_with_network(row, weights_1))

# Calculate the mean squared error for model_output_0: mse_0
mse_0 = mean_squared_error(target_actuals, model_output_0)

# Calculate the mean squared error for model_output_1: mse_1
mse_1 = mean_squared_error(target_actuals, model_output_1)

# Print mse_0 and mse_1
print("Mean squared error with weights_0: %f" %mse_0)
print("Mean squared error with weights_1: %f" %mse_1)
# Out:
# Mean squared error with weights_0: 37.500000
# Mean squared error with weights_1: 49.890625

# %% [markdown]
# <img src="slope.png" width="400">

# %%
# Calculate the predictions: preds
weights = np.array([0, 2, 1])
input_data = np.array([1, 2, 3])
target = 0

preds = (weights * input_data).sum()

# Calculate the error: error
error = preds - target

# Calculate the slope: slope
slope = input_data * error * 2

# Print the slope
print(slope)
# Out:
# [14 28 42]

# %%
# Set the learning rate: learning_rate
learning_rate = 0.01

# Calculate the predictions: preds
preds = (weights * input_data).sum()

# Calculate the error: error
error = preds - target

# Calculate the slope: slope
slope = 2 * input_data * error

# Update the weights: weights_updated
weights_updated = weights - learning_rate * slope

# Get updated predictions: preds_updated
preds_updated = (weights_updated * input_data).sum()

# Calculate updated error: error_updated
error_updated = preds_updated - target

# Print the original error
print(error)

# Print the updated error
print(error_updated)
# Out:
# 7
# 5.04

# %%
import matplotlib.pyplot as plt

n_updates = 20
mse_hist = []
input_data = np.array([1, 2, 3])
target = 0
weights = np.array([-0.49929916,  1.00140168, -0.49789747])

def get_slope(input_data, target, weights):
    preds = (weights * input_data).sum()
    error = preds - target 
    return input_data * error * 2

def get_mse(input_data, target, weights):
    preds = (weights * input_data).sum()
    return mean_squared_error([preds], [target])

# Iterate over the number of updates
for i in range(n_updates):
    # Calculate the slope: slope
    slope = get_slope(input_data, target, weights)
    #print(slope)
    # Update the weights: weights
    weights = weights - 0.01 * slope
    #print(weights)
    # Calculate mse with new weights: mse
    mse = get_mse(input_data, target, weights)
    #print(mse)
    # Append the mse to mse_hist
    mse_hist.append(mse)

# Plot the mse history
plt.plot(mse_hist)
plt.xlabel('Iterations')
plt.ylabel('Mean Squared Error')
plt.show()

# %% [markdown]
# <img src="NN_C8.png" width="400">

# %% [markdown]
# <img src="NN_C9.png" width="400">

# %% [markdown]
# <img src="newweights.png" width="200">

# %% [markdown]
# ## Creating a `keras` model
#
# There are a few different libraries at our disposal for creating a neural network model:
#
# <img src="libraries.png" width="400">
#
# Here, we will go with `keras`.

# %%
# Complete tutorial: https://hackernoon.com/build-your-first-neural-network-to-predict-house-prices-with-keras-3fb0839680f4
import pandas as pd

df = pd.read_csv('housepricedata.csv')
df.head()
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]], dtype=int64)

# %%
X = dataset[:,0:10]

# %%
Y = dataset[:,10]

# %%
Y
# Out:
# array([1, 1, 1, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %% [markdown]
# ### Setting up the architecture

# %% [markdown]
# The architecture that we want to implement is this:
#
# <img src="architecture.png" width="400">
#
# - Hidden layer 1: 32 neurons, ReLU activation
# - Hidden layer 2: 32 neurons, ReLU activation
# - Output Layer: 1 neuron, Sigmoid activation

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From c:\Users\x360\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
#  sequentially (layer by layer)
#  ‘Dense’ refers to a fully-connected layer
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])
# Out:
# WARNING:tensorflow:From c:\Users\x360\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# ‘sgd’ refers to stochastic gradient descent
# The loss function for outputs that take the values 1 or 0 is called binary cross entropy.
# we want to track accuracy on top of the loss function
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\x360\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=120,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/120
# WARNING:tensorflow:From c:\Users\x360\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\x360\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 32/32 [==============================] - 2s 13ms/step - loss: 0.6897 - accuracy: 0.5176 - val_loss: 0.6844 - val_accuracy: 0.5982
# Epoch 2/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6829 - accuracy: 0.6243 - val_loss: 0.6773 - val_accuracy: 0.7260
# Epoch 3/120
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.7299 - val_loss: 0.6715 - val_accuracy: 0.7763
# Epoch 4/120
# 32/32 [==============================] - 0s 9ms/step - loss: 0.6714 - accuracy: 0.7583 - val_loss: 0.6655 - val_accuracy: 0.7945
# Epoch 5/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6657 - accuracy: 0.7818 - val_loss: 0.6589 - val_accuracy: 0.8082
# Epoch 6/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6599 - accuracy: 0.7975 - val_loss: 0.6533 - val_accuracy: 0.8082
# Epoch 7/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6549 - accuracy: 0.7984 - val_loss: 0.6480 - val_accuracy: 0.8265
# Epoch 8/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6502 - accuracy: 0.8014 - val_loss: 0.6430 - val_accuracy: 0.8265
# Epoch 9/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6454 - accuracy: 0.7994 - val_loss: 0.6379 - val_accuracy: 0.8311
# Epoch 10/120
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6407 - accuracy: 0.8063 - val_loss: 0.6326 - val_accuracy: 0.8356
# Epoch 11/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6361 - accuracy: 0.8121 - val_loss: 0.6273 - val_accuracy: 0.8447
# Epoch 12/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6311 - accuracy: 0.8141 - val_loss: 0.6218 - val_accuracy: 0.8402
# Epoch 13/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.8102 - val_loss: 0.6162 - val_accuracy: 0.8447
# Epoch 14/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6205 - accuracy: 0.8160 - val_loss: 0.6101 - val_accuracy: 0.8539
# Epoch 15/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6150 - accuracy: 0.8229 - val_loss: 0.6039 - val_accuracy: 0.8447
# Epoch 16/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6092 - accuracy: 0.8180 - val_loss: 0.5975 - val_accuracy: 0.8402
# Epoch 17/120
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6031 - accuracy: 0.8170 - val_loss: 0.5905 - val_accuracy: 0.8493
# Epoch 18/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5967 - accuracy: 0.8151 - val_loss: 0.5832 - val_accuracy: 0.8584
# Epoch 19/120
# 32/32 [==============================] - 0s 9ms/step - loss: 0.5901 - accuracy: 0.8278 - val_loss: 0.5756 - val_accuracy: 0.8630
# Epoch 20/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5832 - accuracy: 0.8297 - val_loss: 0.5679 - val_accuracy: 0.8630
# Epoch 21/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5759 - accuracy: 0.8307 - val_loss: 0.5603 - val_accuracy: 0.8493
# Epoch 22/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5683 - accuracy: 0.8268 - val_loss: 0.5520 - val_accuracy: 0.8493
# Epoch 23/120
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5605 - accuracy: 0.8268 - val_loss: 0.5433 - val_accuracy: 0.8584
# Epoch 24/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5526 - accuracy: 0.8297 - val_loss: 0.5344 - val_accuracy: 0.8584
# Epoch 25/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5443 - accuracy: 0.8327 - val_loss: 0.5255 - val_accuracy: 0.8584
# Epoch 26/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5359 - accuracy: 0.8307 - val_loss: 0.5159 - val_accuracy: 0.8676
# Epoch 27/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5273 - accuracy: 0.8376 - val_loss: 0.5064 - val_accuracy: 0.8767
# Epoch 28/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5187 - accuracy: 0.8386 - val_loss: 0.4974 - val_accuracy: 0.8584
# Epoch 29/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5098 - accuracy: 0.8425 - val_loss: 0.4893 - val_accuracy: 0.8402
# Epoch 30/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5011 - accuracy: 0.8415 - val_loss: 0.4789 - val_accuracy: 0.8630
# Epoch 31/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4925 - accuracy: 0.8415 - val_loss: 0.4690 - val_accuracy: 0.8767
# Epoch 32/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4836 - accuracy: 0.8454 - val_loss: 0.4592 - val_accuracy: 0.8813
# Epoch 33/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4751 - accuracy: 0.8523 - val_loss: 0.4519 - val_accuracy: 0.8584
# Epoch 34/120
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4666 - accuracy: 0.8454 - val_loss: 0.4415 - val_accuracy: 0.8813
# Epoch 35/120
# 32/32 [==============================] - 0s 8ms/step - loss: 0.4584 - accuracy: 0.8513 - val_loss: 0.4330 - val_accuracy: 0.8813
# Epoch 36/120
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4503 - accuracy: 0.8532 - val_loss: 0.4251 - val_accuracy: 0.8767
# Epoch 37/120
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4427 - accuracy: 0.8542 - val_loss: 0.4170 - val_accuracy: 0.8813
# Epoch 38/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4352 - accuracy: 0.8493 - val_loss: 0.4072 - val_accuracy: 0.8904
# Epoch 39/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4280 - accuracy: 0.8562 - val_loss: 0.4008 - val_accuracy: 0.8950
# Epoch 40/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4216 - accuracy: 0.8562 - val_loss: 0.3928 - val_accuracy: 0.8995
# Epoch 41/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4145 - accuracy: 0.8630 - val_loss: 0.3864 - val_accuracy: 0.9041
# Epoch 42/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4080 - accuracy: 0.8611 - val_loss: 0.3790 - val_accuracy: 0.9041
# Epoch 43/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4020 - accuracy: 0.8630 - val_loss: 0.3728 - val_accuracy: 0.9087
# Epoch 44/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3964 - accuracy: 0.8640 - val_loss: 0.3678 - val_accuracy: 0.9087
# Epoch 45/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3910 - accuracy: 0.8620 - val_loss: 0.3632 - val_accuracy: 0.9041
# Epoch 46/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3857 - accuracy: 0.8581 - val_loss: 0.3568 - val_accuracy: 0.9041
# Epoch 47/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3809 - accuracy: 0.8611 - val_loss: 0.3498 - val_accuracy: 0.9041
# Epoch 48/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3765 - accuracy: 0.8718 - val_loss: 0.3468 - val_accuracy: 0.9041
# Epoch 49/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3722 - accuracy: 0.8650 - val_loss: 0.3433 - val_accuracy: 0.9041
# Epoch 50/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8640 - val_loss: 0.3374 - val_accuracy: 0.8995
# Epoch 51/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3637 - accuracy: 0.8689 - val_loss: 0.3306 - val_accuracy: 0.8995
# Epoch 52/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3606 - accuracy: 0.8708 - val_loss: 0.3302 - val_accuracy: 0.9041
# Epoch 53/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3568 - accuracy: 0.8669 - val_loss: 0.3255 - val_accuracy: 0.8995
# Epoch 54/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3535 - accuracy: 0.8718 - val_loss: 0.3236 - val_accuracy: 0.9041
# Epoch 55/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3503 - accuracy: 0.8679 - val_loss: 0.3193 - val_accuracy: 0.8995
# Epoch 56/120
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3476 - accuracy: 0.8689 - val_loss: 0.3155 - val_accuracy: 0.8995
# Epoch 57/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3448 - accuracy: 0.8699 - val_loss: 0.3130 - val_accuracy: 0.8995
# Epoch 58/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3422 - accuracy: 0.8708 - val_loss: 0.3090 - val_accuracy: 0.8995
# Epoch 59/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3401 - accuracy: 0.8708 - val_loss: 0.3055 - val_accuracy: 0.8995
# Epoch 60/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3372 - accuracy: 0.8718 - val_loss: 0.3007 - val_accuracy: 0.8995
# Epoch 61/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3358 - accuracy: 0.8718 - val_loss: 0.3035 - val_accuracy: 0.8950
# Epoch 62/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3332 - accuracy: 0.8728 - val_loss: 0.3007 - val_accuracy: 0.8950
# Epoch 63/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3310 - accuracy: 0.8728 - val_loss: 0.3003 - val_accuracy: 0.8950
# Epoch 64/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3300 - accuracy: 0.8728 - val_loss: 0.2957 - val_accuracy: 0.8950
# Epoch 65/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3271 - accuracy: 0.8748 - val_loss: 0.2915 - val_accuracy: 0.8950
# Epoch 66/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3257 - accuracy: 0.8718 - val_loss: 0.2947 - val_accuracy: 0.8950
# Epoch 67/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3241 - accuracy: 0.8748 - val_loss: 0.2883 - val_accuracy: 0.8950
# Epoch 68/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3224 - accuracy: 0.8738 - val_loss: 0.2846 - val_accuracy: 0.8950
# Epoch 69/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3215 - accuracy: 0.8728 - val_loss: 0.2878 - val_accuracy: 0.8950
# Epoch 70/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3201 - accuracy: 0.8738 - val_loss: 0.2856 - val_accuracy: 0.8950
# Epoch 71/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3184 - accuracy: 0.8757 - val_loss: 0.2821 - val_accuracy: 0.8950
# Epoch 72/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3171 - accuracy: 0.8748 - val_loss: 0.2811 - val_accuracy: 0.8950
# Epoch 73/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3161 - accuracy: 0.8738 - val_loss: 0.2807 - val_accuracy: 0.8950
# Epoch 74/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3148 - accuracy: 0.8728 - val_loss: 0.2801 - val_accuracy: 0.8950
# Epoch 75/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3131 - accuracy: 0.8738 - val_loss: 0.2733 - val_accuracy: 0.8904
# Epoch 76/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3136 - accuracy: 0.8757 - val_loss: 0.2747 - val_accuracy: 0.8950
# Epoch 77/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3106 - accuracy: 0.8728 - val_loss: 0.2828 - val_accuracy: 0.8995
# Epoch 78/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3104 - accuracy: 0.8767 - val_loss: 0.2801 - val_accuracy: 0.8995
# Epoch 79/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3094 - accuracy: 0.8796 - val_loss: 0.2724 - val_accuracy: 0.8950
# Epoch 80/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3081 - accuracy: 0.8787 - val_loss: 0.2678 - val_accuracy: 0.8904
# Epoch 81/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3076 - accuracy: 0.8748 - val_loss: 0.2697 - val_accuracy: 0.8950
# Epoch 82/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3064 - accuracy: 0.8757 - val_loss: 0.2727 - val_accuracy: 0.8995
# Epoch 83/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3056 - accuracy: 0.8806 - val_loss: 0.2697 - val_accuracy: 0.8995
# Epoch 84/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3045 - accuracy: 0.8787 - val_loss: 0.2626 - val_accuracy: 0.8950
# Epoch 85/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3045 - accuracy: 0.8777 - val_loss: 0.2635 - val_accuracy: 0.8950
# Epoch 86/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3042 - accuracy: 0.8796 - val_loss: 0.2657 - val_accuracy: 0.8995
# Epoch 87/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3022 - accuracy: 0.8816 - val_loss: 0.2626 - val_accuracy: 0.9041
# Epoch 88/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3019 - accuracy: 0.8787 - val_loss: 0.2666 - val_accuracy: 0.8995
# Epoch 89/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3008 - accuracy: 0.8806 - val_loss: 0.2587 - val_accuracy: 0.8950
# Epoch 90/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3006 - accuracy: 0.8826 - val_loss: 0.2617 - val_accuracy: 0.9041
# Epoch 91/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2996 - accuracy: 0.8796 - val_loss: 0.2566 - val_accuracy: 0.8950
# Epoch 92/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2986 - accuracy: 0.8796 - val_loss: 0.2657 - val_accuracy: 0.8995
# Epoch 93/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2987 - accuracy: 0.8806 - val_loss: 0.2585 - val_accuracy: 0.9041
# Epoch 94/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2977 - accuracy: 0.8806 - val_loss: 0.2590 - val_accuracy: 0.9041
# Epoch 95/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2971 - accuracy: 0.8806 - val_loss: 0.2591 - val_accuracy: 0.9041
# Epoch 96/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2968 - accuracy: 0.8816 - val_loss: 0.2597 - val_accuracy: 0.9041
# Epoch 97/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2959 - accuracy: 0.8806 - val_loss: 0.2579 - val_accuracy: 0.9041
# Epoch 98/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2957 - accuracy: 0.8845 - val_loss: 0.2548 - val_accuracy: 0.9041
# Epoch 99/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2947 - accuracy: 0.8796 - val_loss: 0.2563 - val_accuracy: 0.9041
# Epoch 100/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2947 - accuracy: 0.8816 - val_loss: 0.2530 - val_accuracy: 0.9041
# Epoch 101/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2938 - accuracy: 0.8826 - val_loss: 0.2496 - val_accuracy: 0.8995
# Epoch 102/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2931 - accuracy: 0.8826 - val_loss: 0.2540 - val_accuracy: 0.9041
# Epoch 103/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2923 - accuracy: 0.8816 - val_loss: 0.2532 - val_accuracy: 0.9041
# Epoch 104/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2934 - accuracy: 0.8836 - val_loss: 0.2526 - val_accuracy: 0.9041
# Epoch 105/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2916 - accuracy: 0.8875 - val_loss: 0.2501 - val_accuracy: 0.9041
# Epoch 106/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2907 - accuracy: 0.8836 - val_loss: 0.2465 - val_accuracy: 0.8995
# Epoch 107/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2911 - accuracy: 0.8904 - val_loss: 0.2542 - val_accuracy: 0.9041
# Epoch 108/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2900 - accuracy: 0.8845 - val_loss: 0.2473 - val_accuracy: 0.8995
# Epoch 109/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2891 - accuracy: 0.8904 - val_loss: 0.2447 - val_accuracy: 0.8995
# Epoch 110/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2895 - accuracy: 0.8845 - val_loss: 0.2440 - val_accuracy: 0.8995
# Epoch 111/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2890 - accuracy: 0.8855 - val_loss: 0.2442 - val_accuracy: 0.8995
# Epoch 112/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2881 - accuracy: 0.8806 - val_loss: 0.2482 - val_accuracy: 0.9041
# Epoch 113/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2880 - accuracy: 0.8885 - val_loss: 0.2475 - val_accuracy: 0.9041
# Epoch 114/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2877 - accuracy: 0.8836 - val_loss: 0.2441 - val_accuracy: 0.8995
# Epoch 115/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2877 - accuracy: 0.8865 - val_loss: 0.2466 - val_accuracy: 0.9041
# Epoch 116/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2871 - accuracy: 0.8875 - val_loss: 0.2458 - val_accuracy: 0.9041
# Epoch 117/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2866 - accuracy: 0.8845 - val_loss: 0.2485 - val_accuracy: 0.9041
# Epoch 118/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2857 - accuracy: 0.8826 - val_loss: 0.2441 - val_accuracy: 0.9041
# Epoch 119/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2861 - accuracy: 0.8845 - val_loss: 0.2421 - val_accuracy: 0.8995
# Epoch 120/120
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2855 - accuracy: 0.8865 - val_loss: 0.2391 - val_accuracy: 0.8995

# %%
# The reason why we have the index 1 after the model.evaluate function is because the function returns the loss as the first element and the accuracy as the second element.
model.evaluate(X_test, Y_test)[1]
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2335 - accuracy: 0.8995
# 0.8995434045791626

# %% [markdown]
# ### Visualizing loss and accuracy
#
# <img src="graphics.png" width="400">
#
# A good model is one where the testing and training set errors are very similar, and at their lowest point.

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# ### Adding regularization to our network
#
# Our model is overfitting. Similarly to simpler machine learning models, we can add **regularization** to our neural network to help correct this. However, the exact types of regularization are somewhat different than the ones used for our usual classification models, and go by different names:
#
# - L2 Regularization
#     <img src="L2.png" width="200">
# - Early Stopping
#     <img src="Lossgraphic.png" width="200">
# - Dropout
#     <img src="dropout.png" width="400">

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model_2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist_2 = model_2.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 3s 59ms/step - loss: 0.4541 - accuracy: 0.7896 - val_loss: 0.3087 - val_accuracy: 0.8767
# Epoch 2/100
# 32/32 [==============================] - 2s 48ms/step - loss: 0.3543 - accuracy: 0.8493 - val_loss: 0.3332 - val_accuracy: 0.8858
# Epoch 3/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.3499 - accuracy: 0.8425 - val_loss: 0.3576 - val_accuracy: 0.8767
# Epoch 4/100
# 32/32 [==============================] - 2s 55ms/step - loss: 0.3714 - accuracy: 0.8444 - val_loss: 0.2522 - val_accuracy: 0.8813
# Epoch 5/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.3095 - accuracy: 0.8689 - val_loss: 0.2472 - val_accuracy: 0.8950
# Epoch 6/100
# 32/32 [==============================] - 2s 52ms/step - loss: 0.2856 - accuracy: 0.8826 - val_loss: 0.2285 - val_accuracy: 0.9178
# Epoch 7/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.2866 - accuracy: 0.8865 - val_loss: 0.2105 - val_accuracy: 0.8950
# Epoch 8/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2788 - accuracy: 0.8796 - val_loss: 0.2924 - val_accuracy: 0.8950
# Epoch 9/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2672 - accuracy: 0.8914 - val_loss: 0.2214 - val_accuracy: 0.9087
# Epoch 10/100
# 32/32 [==============================] - 2s 48ms/step - loss: 0.2549 - accuracy: 0.8885 - val_loss: 0.1991 - val_accuracy: 0.9087
# Epoch 11/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2811 - accuracy: 0.8836 - val_loss: 0.2326 - val_accuracy: 0.8995
# Epoch 12/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.3020 - accuracy: 0.8708 - val_loss: 0.2058 - val_accuracy: 0.9224
# Epoch 13/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2512 - accuracy: 0.8992 - val_loss: 0.1925 - val_accuracy: 0.9132
# Epoch 14/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2487 - accuracy: 0.8992 - val_loss: 0.2157 - val_accuracy: 0.9132
# Epoch 15/100
# 32/32 [==============================] - 2s 50ms/step - loss: 0.2462 - accuracy: 0.8973 - val_loss: 0.1883 - val_accuracy: 0.9315
# Epoch 16/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.2516 - accuracy: 0.8875 - val_loss: 0.2077 - val_accuracy: 0.9178
# Epoch 17/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.2417 - accuracy: 0.9031 - val_loss: 0.3140 - val_accuracy: 0.8950
# Epoch 18/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2453 - accuracy: 0.8845 - val_loss: 0.2084 - val_accuracy: 0.9315
# Epoch 19/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.2173 - accuracy: 0.9031 - val_loss: 0.1688 - val_accuracy: 0.9224
# Epoch 20/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2388 - accuracy: 0.8933 - val_loss: 0.2011 - val_accuracy: 0.9087
# Epoch 21/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2381 - accuracy: 0.8914 - val_loss: 0.1753 - val_accuracy: 0.9224
# Epoch 22/100
# 32/32 [==============================] - 1s 44ms/step - loss: 0.2345 - accuracy: 0.8982 - val_loss: 0.2078 - val_accuracy: 0.9361
# Epoch 23/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.2184 - accuracy: 0.9022 - val_loss: 0.2077 - val_accuracy: 0.9178
# Epoch 24/100
# 32/32 [==============================] - 2s 50ms/step - loss: 0.2163 - accuracy: 0.9002 - val_loss: 0.1819 - val_accuracy: 0.9224
# Epoch 25/100
# 32/32 [==============================] - 2s 55ms/step - loss: 0.2152 - accuracy: 0.9080 - val_loss: 0.2033 - val_accuracy: 0.9132
# Epoch 26/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2397 - accuracy: 0.8914 - val_loss: 0.2904 - val_accuracy: 0.8584
# Epoch 27/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.2187 - accuracy: 0.9022 - val_loss: 0.2080 - val_accuracy: 0.9269
# Epoch 28/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.2077 - accuracy: 0.9002 - val_loss: 0.1954 - val_accuracy: 0.9132
# Epoch 29/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.2145 - accuracy: 0.9051 - val_loss: 0.2029 - val_accuracy: 0.9224
# Epoch 30/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.2278 - accuracy: 0.9119 - val_loss: 0.2233 - val_accuracy: 0.9132
# Epoch 31/100
# 32/32 [==============================] - 2s 49ms/step - loss: 0.2059 - accuracy: 0.9139 - val_loss: 0.3370 - val_accuracy: 0.8858
# Epoch 32/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2074 - accuracy: 0.9110 - val_loss: 0.2741 - val_accuracy: 0.9269
# Epoch 33/100
# 32/32 [==============================] - 2s 48ms/step - loss: 0.2030 - accuracy: 0.9051 - val_loss: 0.2261 - val_accuracy: 0.9224
# Epoch 34/100
# 32/32 [==============================] - 2s 49ms/step - loss: 0.1934 - accuracy: 0.9168 - val_loss: 0.1844 - val_accuracy: 0.9315
# Epoch 35/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1984 - accuracy: 0.9031 - val_loss: 0.2465 - val_accuracy: 0.8950
# Epoch 36/100
# 32/32 [==============================] - 2s 48ms/step - loss: 0.2026 - accuracy: 0.9110 - val_loss: 0.2043 - val_accuracy: 0.9087
# Epoch 37/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.2095 - accuracy: 0.9100 - val_loss: 0.4976 - val_accuracy: 0.7717
# Epoch 38/100
# 32/32 [==============================] - 2s 49ms/step - loss: 0.2548 - accuracy: 0.8933 - val_loss: 0.2213 - val_accuracy: 0.9224
# Epoch 39/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.2044 - accuracy: 0.9119 - val_loss: 0.2266 - val_accuracy: 0.9087
# Epoch 40/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.2303 - accuracy: 0.9100 - val_loss: 0.2313 - val_accuracy: 0.9224
# Epoch 41/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.2040 - accuracy: 0.9012 - val_loss: 0.2449 - val_accuracy: 0.9178
# Epoch 42/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.1967 - accuracy: 0.9090 - val_loss: 0.1902 - val_accuracy: 0.9452
# Epoch 43/100
# 32/32 [==============================] - 5s 152ms/step - loss: 0.1909 - accuracy: 0.9149 - val_loss: 0.2146 - val_accuracy: 0.9361
# Epoch 44/100
# 32/32 [==============================] - 3s 103ms/step - loss: 0.1864 - accuracy: 0.9070 - val_loss: 0.2952 - val_accuracy: 0.8676
# Epoch 45/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.1882 - accuracy: 0.9149 - val_loss: 0.2076 - val_accuracy: 0.9269
# Epoch 46/100
# 32/32 [==============================] - 3s 79ms/step - loss: 0.1828 - accuracy: 0.9178 - val_loss: 0.2029 - val_accuracy: 0.9361
# Epoch 47/100
# 32/32 [==============================] - 4s 116ms/step - loss: 0.1874 - accuracy: 0.9100 - val_loss: 0.2005 - val_accuracy: 0.9224
# Epoch 48/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1813 - accuracy: 0.9159 - val_loss: 0.2213 - val_accuracy: 0.9224
# Epoch 49/100
# 32/32 [==============================] - 3s 79ms/step - loss: 0.1763 - accuracy: 0.9227 - val_loss: 0.3284 - val_accuracy: 0.8858
# Epoch 50/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.2070 - accuracy: 0.9061 - val_loss: 0.2565 - val_accuracy: 0.8950
# Epoch 51/100
# 32/32 [==============================] - 4s 112ms/step - loss: 0.1765 - accuracy: 0.9217 - val_loss: 0.3471 - val_accuracy: 0.9041
# Epoch 52/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.1743 - accuracy: 0.9119 - val_loss: 0.2433 - val_accuracy: 0.9269
# Epoch 53/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.2055 - accuracy: 0.9061 - val_loss: 0.2104 - val_accuracy: 0.9178
# Epoch 54/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.2100 - accuracy: 0.9139 - val_loss: 0.1951 - val_accuracy: 0.9361
# Epoch 55/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.1831 - accuracy: 0.9188 - val_loss: 0.2291 - val_accuracy: 0.9315
# Epoch 56/100
# 32/32 [==============================] - 6s 182ms/step - loss: 0.1958 - accuracy: 0.9188 - val_loss: 0.2167 - val_accuracy: 0.9361
# Epoch 57/100
# 32/32 [==============================] - 4s 131ms/step - loss: 0.1769 - accuracy: 0.9247 - val_loss: 0.2116 - val_accuracy: 0.9315
# Epoch 58/100
# 32/32 [==============================] - 4s 132ms/step - loss: 0.1932 - accuracy: 0.9129 - val_loss: 0.3420 - val_accuracy: 0.8447
# Epoch 59/100
# 32/32 [==============================] - 3s 98ms/step - loss: 0.2278 - accuracy: 0.8992 - val_loss: 0.1968 - val_accuracy: 0.9178
# Epoch 60/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.1888 - accuracy: 0.9198 - val_loss: 0.2005 - val_accuracy: 0.9269
# Epoch 61/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.1770 - accuracy: 0.9207 - val_loss: 0.2093 - val_accuracy: 0.9361
# Epoch 62/100
# 32/32 [==============================] - 3s 77ms/step - loss: 0.1723 - accuracy: 0.9247 - val_loss: 0.2411 - val_accuracy: 0.9132
# Epoch 63/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.1652 - accuracy: 0.9256 - val_loss: 0.2293 - val_accuracy: 0.9361
# Epoch 64/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1524 - accuracy: 0.9315 - val_loss: 0.2579 - val_accuracy: 0.9315
# Epoch 65/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.1521 - accuracy: 0.9364 - val_loss: 0.3469 - val_accuracy: 0.9178
# Epoch 66/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1748 - accuracy: 0.9227 - val_loss: 0.4022 - val_accuracy: 0.8904
# Epoch 67/100
# 32/32 [==============================] - 2s 78ms/step - loss: 0.1649 - accuracy: 0.9295 - val_loss: 0.2512 - val_accuracy: 0.9269
# Epoch 68/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.1499 - accuracy: 0.9413 - val_loss: 0.2443 - val_accuracy: 0.9132
# Epoch 69/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.1468 - accuracy: 0.9354 - val_loss: 0.2931 - val_accuracy: 0.9315
# Epoch 70/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.1766 - accuracy: 0.9168 - val_loss: 0.3566 - val_accuracy: 0.8813
# Epoch 71/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.1735 - accuracy: 0.9159 - val_loss: 0.3074 - val_accuracy: 0.9132
# Epoch 72/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1623 - accuracy: 0.9325 - val_loss: 0.2423 - val_accuracy: 0.9178
# Epoch 73/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1588 - accuracy: 0.9305 - val_loss: 0.2115 - val_accuracy: 0.9361
# Epoch 74/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.1471 - accuracy: 0.9374 - val_loss: 0.3718 - val_accuracy: 0.9087
# Epoch 75/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1420 - accuracy: 0.9393 - val_loss: 0.2699 - val_accuracy: 0.9224
# Epoch 76/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.1913 - accuracy: 0.9256 - val_loss: 0.3110 - val_accuracy: 0.9087
# Epoch 77/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.1721 - accuracy: 0.9286 - val_loss: 0.2158 - val_accuracy: 0.9498
# Epoch 78/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.1505 - accuracy: 0.9344 - val_loss: 0.3925 - val_accuracy: 0.9224
# Epoch 79/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.1477 - accuracy: 0.9335 - val_loss: 0.3209 - val_accuracy: 0.9132
# Epoch 80/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1350 - accuracy: 0.9374 - val_loss: 0.3073 - val_accuracy: 0.9087
# Epoch 81/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.1300 - accuracy: 0.9442 - val_loss: 0.2936 - val_accuracy: 0.9269
# Epoch 82/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.1884 - accuracy: 0.9119 - val_loss: 0.2041 - val_accuracy: 0.9315
# Epoch 83/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.1849 - accuracy: 0.9188 - val_loss: 0.2383 - val_accuracy: 0.9315
# Epoch 84/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.1439 - accuracy: 0.9452 - val_loss: 0.2196 - val_accuracy: 0.9406
# Epoch 85/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.1369 - accuracy: 0.9423 - val_loss: 0.2601 - val_accuracy: 0.9269
# Epoch 86/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.1284 - accuracy: 0.9481 - val_loss: 0.2955 - val_accuracy: 0.9178
# Epoch 87/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.1325 - accuracy: 0.9423 - val_loss: 0.3485 - val_accuracy: 0.9041
# Epoch 88/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1390 - accuracy: 0.9335 - val_loss: 0.3007 - val_accuracy: 0.8950
# Epoch 89/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.1731 - accuracy: 0.9276 - val_loss: 0.2436 - val_accuracy: 0.9406
# Epoch 90/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.1406 - accuracy: 0.9442 - val_loss: 0.3229 - val_accuracy: 0.9178
# Epoch 91/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.1287 - accuracy: 0.9442 - val_loss: 0.2780 - val_accuracy: 0.8950
# Epoch 92/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.1670 - accuracy: 0.9374 - val_loss: 0.2889 - val_accuracy: 0.9132
# Epoch 93/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.1283 - accuracy: 0.9491 - val_loss: 0.2516 - val_accuracy: 0.9132
# Epoch 94/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.1338 - accuracy: 0.9530 - val_loss: 0.2693 - val_accuracy: 0.9224
# Epoch 95/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.1213 - accuracy: 0.9511 - val_loss: 0.2914 - val_accuracy: 0.9315
# Epoch 96/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.1268 - accuracy: 0.9403 - val_loss: 0.3046 - val_accuracy: 0.9178
# Epoch 97/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.1705 - accuracy: 0.9237 - val_loss: 0.3792 - val_accuracy: 0.8630
# Epoch 98/100
# 32/32 [==============================] - 3s 99ms/step - loss: 0.1740 - accuracy: 0.9217 - val_loss: 0.2705 - val_accuracy: 0.9087
# Epoch 99/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.1352 - accuracy: 0.9481 - val_loss: 0.2535 - val_accuracy: 0.9269
# Epoch 100/100
# 32/32 [==============================] - 4s 115ms/step - loss: 0.1080 - accuracy: 0.9560 - val_loss: 0.3485 - val_accuracy: 0.8950

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_2.history['accuracy'])
plt.plot(hist_2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
from keras.layers import Dropout
from keras import regularizers

# %%
model_3 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])

# %%
model_3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist_3 = model_3.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 8s 97ms/step - loss: 14.2207 - accuracy: 0.6145 - val_loss: 3.9129 - val_accuracy: 0.6438
# Epoch 2/100
# 32/32 [==============================] - 2s 74ms/step - loss: 1.6937 - accuracy: 0.7710 - val_loss: 0.6074 - val_accuracy: 0.8858
# Epoch 3/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.5778 - accuracy: 0.8532 - val_loss: 0.4944 - val_accuracy: 0.8904
# Epoch 4/100
# 32/32 [==============================] - 3s 79ms/step - loss: 0.5072 - accuracy: 0.8591 - val_loss: 0.4449 - val_accuracy: 0.8995
# Epoch 5/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.4891 - accuracy: 0.8659 - val_loss: 0.4344 - val_accuracy: 0.8950
# Epoch 6/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.5018 - accuracy: 0.8523 - val_loss: 0.5051 - val_accuracy: 0.8584
# Epoch 7/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.4909 - accuracy: 0.8738 - val_loss: 0.4269 - val_accuracy: 0.8950
# Epoch 8/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.4896 - accuracy: 0.8659 - val_loss: 0.4219 - val_accuracy: 0.8995
# Epoch 9/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.4732 - accuracy: 0.8748 - val_loss: 0.5162 - val_accuracy: 0.8447
# Epoch 10/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.4789 - accuracy: 0.8630 - val_loss: 0.4303 - val_accuracy: 0.8950
# Epoch 11/100
# 32/32 [==============================] - 3s 111ms/step - loss: 0.4680 - accuracy: 0.8806 - val_loss: 0.4417 - val_accuracy: 0.9087
# Epoch 12/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4777 - accuracy: 0.8738 - val_loss: 0.4179 - val_accuracy: 0.8950
# Epoch 13/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.4648 - accuracy: 0.8738 - val_loss: 0.4161 - val_accuracy: 0.9087
# Epoch 14/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4582 - accuracy: 0.8748 - val_loss: 0.4152 - val_accuracy: 0.9041
# Epoch 15/100
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4638 - accuracy: 0.8806 - val_loss: 0.4048 - val_accuracy: 0.8950
# Epoch 16/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4609 - accuracy: 0.8738 - val_loss: 0.4082 - val_accuracy: 0.8904
# Epoch 17/100
# 32/32 [==============================] - 3s 94ms/step - loss: 0.4587 - accuracy: 0.8845 - val_loss: 0.4014 - val_accuracy: 0.8995
# Epoch 18/100
# 32/32 [==============================] - 3s 74ms/step - loss: 0.4771 - accuracy: 0.8699 - val_loss: 0.4166 - val_accuracy: 0.8904
# Epoch 19/100
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4593 - accuracy: 0.8748 - val_loss: 0.4019 - val_accuracy: 0.9041
# Epoch 20/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.4787 - accuracy: 0.8591 - val_loss: 0.3972 - val_accuracy: 0.9087
# Epoch 21/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.4661 - accuracy: 0.8630 - val_loss: 0.4031 - val_accuracy: 0.8995
# Epoch 22/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.4560 - accuracy: 0.8748 - val_loss: 0.4136 - val_accuracy: 0.9087
# Epoch 23/100
# 32/32 [==============================] - 3s 97ms/step - loss: 0.4458 - accuracy: 0.8855 - val_loss: 0.4509 - val_accuracy: 0.8858
# Epoch 24/100
# 32/32 [==============================] - 4s 111ms/step - loss: 0.4597 - accuracy: 0.8738 - val_loss: 0.3903 - val_accuracy: 0.9087
# Epoch 25/100
# 32/32 [==============================] - 4s 110ms/step - loss: 0.4705 - accuracy: 0.8620 - val_loss: 0.4124 - val_accuracy: 0.9041
# Epoch 26/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.4751 - accuracy: 0.8708 - val_loss: 0.4119 - val_accuracy: 0.9041
# Epoch 27/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.4574 - accuracy: 0.8659 - val_loss: 0.4270 - val_accuracy: 0.9087
# Epoch 28/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.4538 - accuracy: 0.8728 - val_loss: 0.3911 - val_accuracy: 0.8950
# Epoch 29/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.4477 - accuracy: 0.8933 - val_loss: 0.4131 - val_accuracy: 0.9132
# Epoch 30/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.4482 - accuracy: 0.8787 - val_loss: 0.4107 - val_accuracy: 0.9178
# Epoch 31/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.4917 - accuracy: 0.8493 - val_loss: 0.4014 - val_accuracy: 0.8950
# Epoch 32/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.4508 - accuracy: 0.8806 - val_loss: 0.3935 - val_accuracy: 0.9041
# Epoch 33/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.4507 - accuracy: 0.8806 - val_loss: 0.3962 - val_accuracy: 0.9041
# Epoch 34/100
# 32/32 [==============================] - 3s 97ms/step - loss: 0.4645 - accuracy: 0.8620 - val_loss: 0.4100 - val_accuracy: 0.9041
# Epoch 35/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.4774 - accuracy: 0.8523 - val_loss: 0.3883 - val_accuracy: 0.9041
# Epoch 36/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.4538 - accuracy: 0.8757 - val_loss: 0.3935 - val_accuracy: 0.8950
# Epoch 37/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.4724 - accuracy: 0.8689 - val_loss: 0.5101 - val_accuracy: 0.8311
# Epoch 38/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.4499 - accuracy: 0.8865 - val_loss: 0.4043 - val_accuracy: 0.9087
# Epoch 39/100
# 32/32 [==============================] - 3s 108ms/step - loss: 0.4534 - accuracy: 0.8816 - val_loss: 0.3849 - val_accuracy: 0.8950
# Epoch 40/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4618 - accuracy: 0.8689 - val_loss: 0.4277 - val_accuracy: 0.9087
# Epoch 41/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4459 - accuracy: 0.8875 - val_loss: 0.3960 - val_accuracy: 0.8904
# Epoch 42/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4565 - accuracy: 0.8728 - val_loss: 0.3926 - val_accuracy: 0.8995
# Epoch 43/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4646 - accuracy: 0.8816 - val_loss: 0.3983 - val_accuracy: 0.9087
# Epoch 44/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.4622 - accuracy: 0.8777 - val_loss: 0.4574 - val_accuracy: 0.8858
# Epoch 45/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4663 - accuracy: 0.8728 - val_loss: 0.4049 - val_accuracy: 0.9087
# Epoch 46/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.4436 - accuracy: 0.8738 - val_loss: 0.5333 - val_accuracy: 0.8265
# Epoch 47/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4514 - accuracy: 0.8708 - val_loss: 0.5156 - val_accuracy: 0.8265
# Epoch 48/100
# 32/32 [==============================] - 3s 103ms/step - loss: 0.4773 - accuracy: 0.8591 - val_loss: 0.4120 - val_accuracy: 0.9041
# Epoch 49/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4532 - accuracy: 0.8836 - val_loss: 0.3952 - val_accuracy: 0.9041
# Epoch 50/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.4470 - accuracy: 0.8777 - val_loss: 0.3819 - val_accuracy: 0.8950
# Epoch 51/100
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4576 - accuracy: 0.8699 - val_loss: 0.3873 - val_accuracy: 0.9087
# Epoch 52/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.4720 - accuracy: 0.8679 - val_loss: 0.3837 - val_accuracy: 0.8950
# Epoch 53/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4522 - accuracy: 0.8885 - val_loss: 0.5406 - val_accuracy: 0.7991
# Epoch 54/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.4565 - accuracy: 0.8757 - val_loss: 0.3848 - val_accuracy: 0.9041
# Epoch 55/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.4414 - accuracy: 0.8806 - val_loss: 0.3887 - val_accuracy: 0.8950
# Epoch 56/100
# 32/32 [==============================] - 3s 79ms/step - loss: 0.4628 - accuracy: 0.8601 - val_loss: 0.3955 - val_accuracy: 0.9041
# Epoch 57/100
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4413 - accuracy: 0.8767 - val_loss: 0.4768 - val_accuracy: 0.8539
# Epoch 58/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4575 - accuracy: 0.8757 - val_loss: 0.4132 - val_accuracy: 0.9178
# Epoch 59/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.4546 - accuracy: 0.8728 - val_loss: 0.4414 - val_accuracy: 0.8950
# Epoch 60/100
# 32/32 [==============================] - 4s 117ms/step - loss: 0.4760 - accuracy: 0.8640 - val_loss: 0.3989 - val_accuracy: 0.9087
# Epoch 61/100
# 32/32 [==============================] - 3s 103ms/step - loss: 0.4579 - accuracy: 0.8718 - val_loss: 0.3874 - val_accuracy: 0.9087
# Epoch 62/100
# 32/32 [==============================] - 4s 113ms/step - loss: 0.4629 - accuracy: 0.8669 - val_loss: 0.3885 - val_accuracy: 0.8995
# Epoch 63/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.4477 - accuracy: 0.8806 - val_loss: 0.3921 - val_accuracy: 0.9041
# Epoch 64/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.4381 - accuracy: 0.8836 - val_loss: 0.3978 - val_accuracy: 0.9041
# Epoch 65/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.4776 - accuracy: 0.8630 - val_loss: 0.4041 - val_accuracy: 0.9041
# Epoch 66/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.4529 - accuracy: 0.8699 - val_loss: 0.4233 - val_accuracy: 0.9087
# Epoch 67/100
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4569 - accuracy: 0.8669 - val_loss: 0.3893 - val_accuracy: 0.8995
# Epoch 68/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.4673 - accuracy: 0.8718 - val_loss: 0.4354 - val_accuracy: 0.8767
# Epoch 69/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.4600 - accuracy: 0.8699 - val_loss: 0.3855 - val_accuracy: 0.9087
# Epoch 70/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.4448 - accuracy: 0.8816 - val_loss: 0.3950 - val_accuracy: 0.9041
# Epoch 71/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.4371 - accuracy: 0.8738 - val_loss: 0.3776 - val_accuracy: 0.9041
# Epoch 72/100
# 32/32 [==============================] - 3s 78ms/step - loss: 0.4373 - accuracy: 0.8718 - val_loss: 0.3846 - val_accuracy: 0.8950
# Epoch 73/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4470 - accuracy: 0.8767 - val_loss: 0.4265 - val_accuracy: 0.9041
# Epoch 74/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.4464 - accuracy: 0.8855 - val_loss: 0.3803 - val_accuracy: 0.8950
# Epoch 75/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.4679 - accuracy: 0.8757 - val_loss: 0.4043 - val_accuracy: 0.9041
# Epoch 76/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.4630 - accuracy: 0.8659 - val_loss: 0.3884 - val_accuracy: 0.8950
# Epoch 77/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.4421 - accuracy: 0.8796 - val_loss: 0.3743 - val_accuracy: 0.8995
# Epoch 78/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.4823 - accuracy: 0.8591 - val_loss: 0.3890 - val_accuracy: 0.9041
# Epoch 79/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.4601 - accuracy: 0.8787 - val_loss: 0.3839 - val_accuracy: 0.9041
# Epoch 80/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.4477 - accuracy: 0.8728 - val_loss: 0.3942 - val_accuracy: 0.9087
# Epoch 81/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4537 - accuracy: 0.8787 - val_loss: 0.3872 - val_accuracy: 0.8995
# Epoch 82/100
# 32/32 [==============================] - 4s 121ms/step - loss: 0.4842 - accuracy: 0.8581 - val_loss: 0.4180 - val_accuracy: 0.9178
# Epoch 83/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.4484 - accuracy: 0.8787 - val_loss: 0.3951 - val_accuracy: 0.9041
# Epoch 84/100
# 32/32 [==============================] - 4s 124ms/step - loss: 0.4515 - accuracy: 0.8806 - val_loss: 0.3771 - val_accuracy: 0.9041
# Epoch 85/100
# 32/32 [==============================] - 3s 94ms/step - loss: 0.4471 - accuracy: 0.8738 - val_loss: 0.3964 - val_accuracy: 0.9041
# Epoch 86/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4444 - accuracy: 0.8836 - val_loss: 0.3869 - val_accuracy: 0.9132
# Epoch 87/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.4539 - accuracy: 0.8767 - val_loss: 0.3834 - val_accuracy: 0.9087
# Epoch 88/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.4576 - accuracy: 0.8708 - val_loss: 0.3865 - val_accuracy: 0.8904
# Epoch 89/100
# 32/32 [==============================] - 3s 78ms/step - loss: 0.4543 - accuracy: 0.8728 - val_loss: 0.3791 - val_accuracy: 0.8904
# Epoch 90/100
# 32/32 [==============================] - 3s 79ms/step - loss: 0.4490 - accuracy: 0.8855 - val_loss: 0.3813 - val_accuracy: 0.8904
# Epoch 91/100
# 32/32 [==============================] - 4s 113ms/step - loss: 0.4324 - accuracy: 0.8796 - val_loss: 0.3996 - val_accuracy: 0.9041
# Epoch 92/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.4558 - accuracy: 0.8728 - val_loss: 0.3993 - val_accuracy: 0.9132
# Epoch 93/100
# 32/32 [==============================] - 3s 94ms/step - loss: 0.4496 - accuracy: 0.8689 - val_loss: 0.3932 - val_accuracy: 0.8995
# Epoch 94/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.4451 - accuracy: 0.8728 - val_loss: 0.3773 - val_accuracy: 0.8950
# Epoch 95/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.4443 - accuracy: 0.8826 - val_loss: 0.3776 - val_accuracy: 0.8995
# Epoch 96/100
# 32/32 [==============================] - 3s 96ms/step - loss: 0.4467 - accuracy: 0.8806 - val_loss: 0.3847 - val_accuracy: 0.9041
# Epoch 97/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.4450 - accuracy: 0.8757 - val_loss: 0.3814 - val_accuracy: 0.8995
# Epoch 98/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.4578 - accuracy: 0.8728 - val_loss: 0.3928 - val_accuracy: 0.9041
# Epoch 99/100
# 32/32 [==============================] - 3s 77ms/step - loss: 0.4532 - accuracy: 0.8767 - val_loss: 0.4050 - val_accuracy: 0.9041
# Epoch 100/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.4431 - accuracy: 0.8836 - val_loss: 0.4358 - val_accuracy: 0.8950

# %%
plt.plot(hist_3.history['loss'])
plt.plot(hist_3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %%
plt.plot(hist_3.history['accuracy'])
plt.plot(hist_3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
